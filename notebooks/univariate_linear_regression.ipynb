# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../datasets/salary_dataset.csv')

print(df.head())
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (30, 3)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['YearsExperience'], df['Salary'], color='blue', edgecolor='k')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
df = df.drop(columns=['Unnamed: 0'])
print(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
print(df.isnull().sum())
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import importlib
import ml_algorithms.linear_regression
importlib.reload(ml_algorithms.linear_regression)

from ml_algorithms.linear_regression import UnivariateLinearRegression

X = df['YearsExperience'].values  
y = df['Salary'].values          

model = UnivariateLinearRegression()

model.fit(X, y, learning_rate=0.01, epochs=1000)

model.print_parameters()

new_experience = [1.5, 3.0, 5.0]
predicted_salaries = model.predict(new_experience)

print("Predicted Salaries based on Years of Experience:")
for exp, salary in zip(new_experience, predicted_salaries):
    print(f" - {exp} years: ₹{salary:,.2f}")


model.plot_fit(X, y)
# Out:
# Epoch 0: Loss = 514619474.06
# Epoch 100: Loss = 79460869.68
# Epoch 200: Loss = 52416999.28
# Epoch 300: Loss = 40549974.11
# Epoch 400: Loss = 35342646.73
# Epoch 500: Loss = 33057637.82
# Epoch 600: Loss = 32054961.13
# Epoch 700: Loss = 31614980.12
# Epoch 800: Loss = 31421913.61
# Epoch 900: Loss = 31337194.77
# Learned weight (slope): 9504.8013
# Learned bias (intercept): 24474.5576
# Predicted Salaries based on Years of Experience:
#  - 1.5 years: ₹38,731.76
#  - 3.0 years: ₹52,988.96
#  - 5.0 years: ₹71,998.56
