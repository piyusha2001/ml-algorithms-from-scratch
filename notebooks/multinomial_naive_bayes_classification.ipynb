# %%
import pandas as pd

df = pd.read_csv("../datasets/spam.csv", encoding='ISO-8859-1')

df = df.iloc[:, :2]
df.columns = ['label', 'message']

print(df.head())
print(df['label'].value_counts())
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
import re

def preprocess(text):
    text = text.lower()  # Lowercase
    text = re.sub(r'[^a-z0-9\s]', '', text)  # Remove punctuation
    tokens = text.split()  # Tokenize by whitespace
    return tokens

df['tokens'] = df['message'].apply(preprocess)

print(df[['message', 'tokens']].head())
# Out:
#                                              message  \
# 0  Go until jurong point, crazy.. Available only ...
# 1                      Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  U dun say so early hor... U c already then say...
# 4  Nah I don't think he goes to usf, he lives aro...
#
#                                               tokens
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import importlib
import ml_algorithms.naive_bayes
importlib.reload(ml_algorithms.naive_bayes)

from ml_algorithms.naive_bayes import NaiveBayes

nb = NaiveBayes()
nb.fit(df['tokens'], df['label'])

print(nb.get_class_counts())
print(nb.get_vocabulary())
# Out:
# {'ham': 4825, 'spam': 747}
# {'dont', 'go', 'letter', 'safely', '2kbsubject', '09050000555', 'faglord', 'calicut', 'typelyk', 'perpetual', 'hisher', 'shouldnt', 'lots', 'practice', 'unemployed', '88877', 'satisfy', '1stone', 'brolly', 'arty', 'gudk', 'desk', 'blu', '4txt120', 'stage', 'sirs', '09050000928', 'western', 'netflix', 'hugging', 'wwwsmsacunatalie2k9', 'african', 'ctargg', 'shining', 'dehydrated', 'journey', 'robinson', 'bullshit', 'gimmi', 'released', 'logging', 'dahow', '1000call', 'bothering', 'suppliers', 'lunchyou', 'reason', 'simple', 'publish', '18', 'admit', '3350', 'evn', 'hmmmm', 'l8', '7548', '89555', 'bck', 'pretty', '50award', 'swing', 'key', 'bank', 'heartheart', 'safety', '08081263000', 'camp', 'built', 'names', 'oga', 'shant', 'sudn', '08006344447', 'nange', 'um', 'break', 'pictxt', 'm8', 'oni', 'aeroplane', 'unlike', 'zeros', 'm95', 'malarky', 'glasgow', 'innocent', 'darling', 'moneyi', 'checkboxes', 'clothes', 'nasdaq', 'fumbling', 'uslet', '08081560665', 'yeovil', 'sittin', 'speling', 'kr', 'mcat', '6ramaduth', 'inperialmusic', '1hr', '1131', 'towards', 'grow', 'lovers', 'usmle', 'least5times', 'fakemy', 'recount', 'read', 'tears', 'heat', 'suggestions', 'book', 'mustprovide', 'downstem', 'computers', 'railway', 'ofice', 'sian', 'urination', 'ufind', 'farrell', 'correctionor', 'bin', 'east', '532', '88088', 'zogtorius', 'semi', 'inclu', 'chat80155', 'rights', 'tiime', 'wereare', 'virgin', 'freesend', 'appointment', 'call2optoutj5q', 'portal', 'director', '09064017305', 'confuses', 'thank', 'can', 'msgsd', 'owns', 'speed', 'percent', 'sender', 'groundamla', 'loveme', 'backwards', 'drmstake', 'di', 'appendix', 'multiply', 'mathematics', 'kindly', 'lunchtime', 'anyhow', 'haircut', 'single', 's', 'weightloss', 'tscs', 'minutes', 'ultimate', 'gt', 'popcornjust', 'part', 'problemi', 'collection', 'hussey', 'yohere', 'affairs', 'age', 'hi', 'hyde', 'receipt', 'overa', 'emily', 'problems', 'positions', 'nobody', 'southern', 'bcozi', 'judgementali', 'help08714742804', 'kaaj', 'within', 'sue', 'replybe', 'promotion', 'messagestext', 'www4tcbiz', 'nok', 'bec', '10803', 'stadium', 'yupz', 'canteen', 'wined', 'ahhh', 'leannewhat', 'aletter', 'welltake', 'magazine', 'hitechnical', 'callcost', 'ass', 'paragon', 'marandratha', 'apologise', 'nohe', 'das', 'blah', 'breather', 'difficult', 'fight', 'hui', 'izzit', 'includes', '3rd', 'uks', 'bac', 'whos', '08712101358', 'crore', 'namemy', 'ni8swt', '09050001808', 'pen', 'hp20', 'y', 'husband', 'issues', '86021', 'only', 'crowd', 'wer', 'guys', 'ou', 'glory', 'honeydid', 'linerental', 'fails', '80488biz', 'roller', 'give', 'tired', 'cloth', 'lnly', 'leonas', '08718730555', 'tobed', 'duvet', '09050090044', 'amplikater', 'sheet', 'beside', 'santha', 'making', 'normally', 'pants', 'finally', '09061701444', 'announcement', 'raed', 'faithevening', 'rd', 'caveboy', 'slice', 'hm', 'm26', 'hrs', 'spoken', 'tshirt', 'silence', 'marriage', 'anythings', 'kvb', 'lac', 'lifeis', '09064011000', 'charged150pmsg2', 'wordstart', 'complaint', '5we', 'elaborating', 'imposter', 'achieve', 'max', '83222', 'armenia', 'dismissial', '1million', 'yes910', 'theirs', 'london', 'hmmmhow', 'youmoney', 'otside', 'shinco', 'murdered', 'pubs', 'howre', 'lined', 'suitemates', 'olol', 'name1', 'brighten', 'addie', '10th', 'loverakhesh', '450pw', 'jaz', 'wrking', 'behalf', 'murali', 'biolas', 'westonzoyland', 'school', 'gentle', 'snappy', 'xy', 'xafter', 'fondly', '2703', 'karaoke', 'dust', 'shah', 'inpersonation', 'dear', '08704439680tscs', 'keralacircle', 'soil', 'red', 'sumfing', 'flip', 'atten', 'others', 'finest', 'japanese', 'fallen', 'nordstrom', 'txtjourney', 'st', 'things', 'bhayandar', 'link', 'coast', 'pre', 'pretend', 'wiproyou', 'members', 'smsing', 'postcard', 'goodnite', 'grateful', 'fated', 'poem', 'dub', 'sorrowsi', 'mini', 'll', 'fuckinniceselfish', '85222', 'com', 'suply', 'letters', '08704439680', 'postponed', 'rice', 'barolla', 'supervisor', 'useless', 'phones', '3g', 'send', 'body', 'xxxmobilemovieclubcomnqjkg ...

# %%
from utils.train_test_split import train_test_split_custom
import numpy as np

X = np.array(df['tokens'].tolist(), dtype=object)
y = np.array(df['label'].tolist())

X_train, X_test, y_train, y_test = train_test_split_custom(X, y, test_size=0.2)

# %%
from ml_algorithms.naive_bayes import NaiveBayes

nb = NaiveBayes()
nb.fit(X_train, y_train)
# Get predictions for the test set
y_pred = nb.predict(X_test)

accuracy = nb.score(X_test, y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 96.86%
