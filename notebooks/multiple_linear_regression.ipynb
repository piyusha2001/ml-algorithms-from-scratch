# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
# Load CSV
df = pd.read_csv("../datasets/housing.csv", header=None, delimiter=r"\s+", names=column_names)

# Display first few rows
print(df.head())
print("\nColumns:", df.columns)
print("\nShape:", df.shape)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
#
# Columns: Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')
#
# Shape: (506, 14)

# %%
# Check for missing values
print("Any null values?\n", df.isnull().sum())

# Check summary statistics
print("\nBasic statistics:\n", df.describe())
# Out:
# Any null values?
#  CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64
#
# Basic statistics:
#               CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
# ...

# %%
# Separate features and target
X = df.drop(columns='MEDV').values  # shape: (506, 13)
y = df['MEDV'].values.reshape(-1, 1)  # shape: (506, 1)

# Check again
print("Shape of X:", X.shape)
print("First 5 rows of X:\n", X[:5])
# Out:
# Shape of X: (506, 13)
# First 5 rows of X:
#  [[6.3200e-03 1.8000e+01 2.3100e+00 0.0000e+00 5.3800e-01 6.5750e+00
#   6.5200e+01 4.0900e+00 1.0000e+00 2.9600e+02 1.5300e+01 3.9690e+02
#   4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 6.4210e+00
#   7.8900e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9690e+02
#   9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 7.1850e+00
#   6.1100e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9283e+02
#   4.0300e+00]
#  [3.2370e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.9980e+00
#   4.5800e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9463e+02
#   2.9400e+00]
#  [6.9050e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 7.1470e+00
#   5.4200e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9690e+02
#   5.3300e+00]]

# %%
import sys
import os

# Add the parent directory (project root) to the path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import importlib
import ml_algorithms.linear_regression
importlib.reload(ml_algorithms.linear_regression)

from ml_algorithms.linear_regression import MultipleLinearRegression
from utils.scaler import StandardScaler  # Make sure this file exists and is correctly placed

# Step 2: Scale all features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Add the bias term (column of ones) back
X_scaled = np.c_[np.ones(X_scaled.shape[0]), X_scaled]

# Step 4: Train the model
model = MultipleLinearRegression()
model.fit(X_scaled, y)
model.print_parameters()
r2 = model.r2_score(X_scaled, y)
print(f"R² score: {r2:.4f}")

model.plot_predictions(X_scaled, y)
# Out:
# Epoch 0: Loss = 563.4333
# Epoch 100: Loss = 32.5086
# Epoch 200: Loss = 23.0417
# Epoch 300: Loss = 22.5035
# Epoch 400: Loss = 22.2886
# Epoch 500: Loss = 22.1632
# Epoch 600: Loss = 22.0848
# Epoch 700: Loss = 22.0331
# Epoch 800: Loss = 21.9976
# Epoch 900: Loss = 21.9723
# Learned weights: [22.53280629 -0.87243979  0.98514139 -0.0943792   0.71501668 -1.9387766
#   2.73738792 -0.02848829 -3.05546651  2.04939371 -1.41239063 -2.02454969
#   0.85004707 -3.71538521]
# R² score: 0.7399
